# %%
import pandas as pd
import numpy as np
import re
import folium

# %%
data = pd.read_csv("../data/food-inspections.csv")

# %%
food=data.copy()

# %%
# Find all columns with at least one null value
null_cols=np.sum(food.isnull() , axis=0)
null_cols[null_cols>0]
# Out:
# AKA Name                        2457
# License #                         17
# Facility Type                   4779
# Risk                              73
# City                             138
# State                             42
# Zip                               50
# Inspection Type                    1
# Violations                     51935
# Latitude                         688
# Longitude                        688
# Location                         688
# Historical Wards 2003-2015    195796
# Zip Codes                     195796
# Community Areas               195796
# Census Tracts                 195796
# Wards                         195796
# dtype: int64

# %%
food.shape
# Out:
# (195796, 22)

# %% [markdown]
# ### Drop columns

# %% [markdown]
# The columns Historical Wards 2003-2015 , Zip Codes , Community Areas , Census Tracts and Ward are all empty. So we drop them

# %%
food.drop(columns=["Historical Wards 2003-2015","Zip Codes", "Community Areas", "Census Tracts", "Wards"],axis=1,inplace=True)

# %% [markdown]
# ### Results

# %%
food["Results"].value_counts()
# Out:
# Pass                    105795
# Fail                     37870
# Pass w/ Conditions       27105
# Out of Business          16844
# No Entry                  6237
# Not Ready                 1877
# Business Not Located        68
# Name: Results, dtype: int64

# %% [markdown]
# We are interested in business with inspections that pass or fail so we retain those

# %%
results=["Pass","Fail","Pass w/ Conditions"]
food=food[food["Results"].isin(results)]
food.shape
# Out:
# (170770, 17)

# %% [markdown]
# ### Zip

# %% [markdown]
# Since there are only 31 cases with nan zip, we simply drop them

# %%
food=food[~food["Zip"].isnull()]

# %% [markdown]
# ### City and State

# %%
food[food.State.isnull() & food.City.isnull()]["Address"].unique()
# Out:
# array(['636 N RACINE AVE ', '1438 W CORTLAND ST ', '506 N Milwaukee AVE ',
#        '500 N MILWAUKEE AVE '], dtype=object)

# %% [markdown]
# All Null values in State and City are in Chicago ( checked with the respective adresses)

# %%
food[food.State.isnull() & ~food.City.isnull()]["City"].unique()
# Out:
# array(['CHICAGO'], dtype=object)

# %% [markdown]
# Null values in State with a known city are all in Chicago

# %%
food[(food.City.isnull()) & (food["State"]!="IL")]["Address"].unique()
# Out:
# array(['636 N RACINE AVE ', '1438 W CORTLAND ST ', '506 N Milwaukee AVE ',
#        '500 N MILWAUKEE AVE '], dtype=object)

# %% [markdown]
# All Null values in City are in Chicago ( checked with the respective adresses)

# %%
food["State"].fillna("IL", inplace=True)
food=food[food["State"]=="IL"]
food["City"].fillna("Chicago", inplace=True)

# %%
food[food["City"]!="CHICAGO"]["City"].unique()
# Out:
# array(['Chicago', 'chicago', 'SCHAUMBURG', 'ELMHURST', 'ALGONQUIN',
#        'CCHICAGO', 'NILES NILES', 'EVANSTON', 'CHICAGO.',
#        'CHESTNUT STREET', 'LANSING', 'CHICAGOCHICAGO', 'WADSWORTH',
#        'WHEATON', 'CHICAGOHICAGO', 'ROSEMONT', 'CHicago', 'CALUMET CITY',
#        'PLAINFIELD', 'HIGHLAND PARK', 'PALOS PARK', 'ELK GROVE VILLAGE',
#        'BRIDGEVIEW', 'OAK PARK', 'MAYWOOD', 'LAKE BLUFF', '312CHICAGO',
#        'SCHILLER PARK', 'SKOKIE', 'BEDFORD PARK', 'BANNOCKBURNDEERFIELD',
#        'BLOOMINGDALE', 'CICERO', 'Norridge', 'CHCHICAGO', 'SUMMIT',
#        'OOLYMPIA FIELDS', 'CHICAGO HEIGHTS', 'JUSTICE', 'TINLEY PARK',
#        'LOMBARD', 'EAST HAZEL CREST', 'COUNTRY CLUB HILLS', 'STREAMWOOD',
#        'BOLINGBROOK', 'BERWYN', 'BURNHAM', 'DES PLAINES', 'LAKE ZURICH',
#        'OLYMPIA FIELDS', 'OAK LAWN', 'CHICAGOI', 'BLUE ISLAND', 'GLENCOE',
#        'FRANKFORT', 'NAPERVILLE', 'BROADVIEW', 'WORTH', 'Maywood',
#        'CHARLES A HAYES', 'ALSIP', 'EVERGREEN PARK', 'CHCICAGO'],
#       dtype=object)

# %%
Illinois_zipcode=(60001,62999)
suburbs_zipcode=food[food["City"]!="CHICAGO"]["Zip"].unique()
# All the suburbs are within the Illinois zipcode range
all(Illinois_zipcode[0]<=city_zipcode<=Illinois_zipcode[1] for city_zipcode in suburbs_zipcode)
# Out:
# True

# %% [markdown]
# All these values are either typos for Chicago or Chicago suburbs (checked by zip code), so we keep them

# %%
# Fill the null location values with default Chicago location
default_lat=41.85003
default_long=-87.65005
default_location='(-87.65005,41.85003)'
food[food["Location"]==default_location]
# Out:
# Empty DataFrame
# Columns: [Inspection ID, DBA Name, AKA Name, License #, Facility Type, Risk, Address, City, State, Zip, Inspection Date, Inspection Type, Results, Violations, Latitude, Longitude, Location]
# Index: []

# %% [markdown]
# No other business has this location, so we can drop it when we need to plot

# %%
food["Latitude"].fillna(default_lat,inplace=True)
food["Longitude"].fillna(default_long,inplace=True)
food["Location"].fillna(default_location,inplace=True)

# %% [markdown]
# ### License number

# %%
food[food["License #"].isnull()].shape
# Out:
# (16, 17)

# %%
food.groupby("License #").Location.nunique().sort_values(ascending=False).head()
# Out:
# License #
# 0.0          192
# 2458393.0      3
# 2232394.0      2
# 24382.0        2
# 2535189.0      2
# Name: Location, dtype: int64

# %% [markdown]
# Since there are 16 nans, and we see that a lot of unidentified license are set to 0, we set them also to 0

# %%
food["License #"].fillna(0,inplace=True)

# %% [markdown]
# ### Violations

# %% [markdown]
# As seen in the dataset describtion:
#
# An establishment can receive one or more of 45 distinct violations (violation
# numbers 1-44 and 70). For each violation number listed for a given establishment, the
# requirement the establishment must meet in order for it to NOT receive a violation is
# noted, followed by a specific description of the findings that caused the violation to be
# issued.

# %% [markdown]
# For the null values in Violations, we will just replace them with "0. None reported" since the violations are numbered

# %%
food["Violations"].fillna("0. None Reported", inplace=True)

# %% [markdown]
# ### Facility Type

# %%
fvc=food["Facility Type"].value_counts()
fvc[fvc>20].head()
# Out:
# Restaurant                      115170
# Grocery Store                    22043
# School                           11737
# Children's Services Facility      2914
# Bakery                            2519
# Name: Facility Type, dtype: int64

# %%
print("We have {0} other categories for a total number of {1} businesses".format(fvc[fvc<20].shape[0], fvc[fvc<20].sum()))
# Out:
# We have 421 other categories for a total number of 2036 businesses

# %% [markdown]
# Might be interesting to set outliers to other

# %%
lower_than_20 = fvc[fvc<20].index

food.loc[food["Facility Type"].isin(lower_than_20),"Facility Type"] ="other"

# %% [markdown]
# For the null values in Facility Type, we will just replace them with "Unspecified"

# %%
food["Facility Type"].fillna("Unspecified", inplace=True)

# %% [markdown]
# ### Risk

# %%
food["Risk"].value_counts()
# Out:
# Risk 1 (High)      125730
# Risk 2 (Medium)     32957
# Risk 3 (Low)        12010
# All                     5
# Name: Risk, dtype: int64

# %% [markdown]
# 5 entries are marked as Risk : ALL . As we don't know the meaning of it and that those entries contain many null values,
# We choose to drop these entries

# %%
food[food["Risk"].isnull()]["Inspection ID"].count()
# Out:
# 34

# %% [markdown]
# 34 entries in Risk are null, since there is no appropiate way to impute them, we choose to drop them

# %%
food=food[~food["Risk"].isnull()]

# %% [markdown]
# ### AKA Name

# %% [markdown]
# The null values in AKA Name can be replaced with their correspending BDA name

# %%
food.loc[food["AKA Name"].isnull(),"AKA Name"] = food.loc[food["AKA Name"].isnull(),"DBA Name"]

# %% [markdown]
# ### Inspection type

# %% [markdown]
# There only is one nul value for Inspection type, we drop it

# %%
food = food[~food["Inspection Type"].isnull()]

# %% [markdown]
# An inspection can be one of the following types:
#
#     -canvass, the mostcommon type of inspection performed at a frequency relative to the risk of the establishment;
#
#     -consultation, when the inspection is done at the request of the owner prior to the opening of the establishment;
#
#     -complaint, when the inspection is done in response to a complaint against the establishment;
#
#     -license, when the inspection is done as a requirement for the establishment to receive its license to operate;
#
#     -suspect food poisoning, when the inspection is done in response to one or more persons claiming to have gotten ill as a result of eating at the establishment (a specific type of complaint-based inspection);
#
#     -task-force inspection, when an inspection of a bar or tavern is done.
#
# Re-inspections can occur for most types of these inspections and are indicated as such.

# %%
food["Inspection Type"].nunique()
# Out:
# 103

# %% [markdown]
# We observe that we have several inspection's types representing the same thing and thus we can regroup them.

# %%
food["Inspection Type exact"] = food["Inspection Type"].copy()

# %%
food["Inspection Type"] = food["Inspection Type"].map(lambda x: x.lower())
food["Inspection Type"] = food["Inspection Type"].map(lambda x: re.sub('re-', 're', x))
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'reinspection' if ('reinspection' in x ) else x)
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'food poisoning' if ('sfp' in x or 'fbi' in x or 'sick' in x or 'poisoning' in x ) else x)
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'canvass' if ('canvas' in x ) else x)
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'complaint' if ('complaint' in x ) else x)
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'license' if ('license' in x ) else x)
food["Inspection Type"] = food["Inspection Type"].map(lambda x:'task force' if ('task' in x ) else x)

# %% [markdown]
# Staphylococcal food poisoning (SFP) is one of the most common food-borne diseases worldwide.
#
# The FBI or Fungus, Bacteria, and Invertebrates are decomposers.

# %%
food["Inspection Type"].nunique()
# Out:
# 36

# %%
kept = ["canvass", "reinspection", "license", "complaint", "suspected food poisoning", "consultation", "tag removal", "recent inspection", "out of business", "task force", "food poisoning"] 

food["Inspection Type"] = food["Inspection Type"].map(lambda x: x if (x in kept ) else 'other')

# %% [markdown]
# Let's check if we still have nan values:

# %%
null_cols=np.sum(food.isnull() , axis=0)
null_cols[null_cols>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Inspection Date

# %%
food["Inspection Date"]
# Out:
# 0         2019-11-08T00:00:00.000
# 1         2019-11-08T00:00:00.000
# 2         2019-11-08T00:00:00.000
# 4         2019-11-08T00:00:00.000
# 5         2019-11-08T00:00:00.000
#                    ...
# 195791    2010-01-04T00:00:00.000
# 195792    2010-01-04T00:00:00.000
# 195793    2010-01-04T00:00:00.000
# 195794    2010-01-04T00:00:00.000
# 195795    2010-01-04T00:00:00.000
# Name: Inspection Date, Length: 170701, dtype: object

# %% [markdown]
# We transform the inspection date to several columns: Year, Month and Day

# %% [markdown]
# Pour ordi version Haitham:

# %%
# food['Inspection Date'] = food['Inspection Date'].map(lambda x: x.split('/'))
# food['Year'] = food['Inspection Date'].map(lambda x: int(x[2]))
# food['Month'] = food['Inspection Date'].map(lambda x: int(x[0]))
# food['Day'] = food['Inspection Date'].map(lambda x: int(x[1]))
# food = food.drop(columns=['Inspection Date'])

# %% [markdown]
# Pour ordi version Ridha:

# %%
food['Inspection Date'] = food['Inspection Date'].map(lambda x: x.split('-'))
food['Year'] = food['Inspection Date'].map(lambda x: int(x[0]))
food['Month'] = food['Inspection Date'].map(lambda x: int(x[1]))
food['Day'] = food['Inspection Date'].map(lambda x: int(x[2].split('T')[0]))
food = food.drop(columns=['Inspection Date'])

# %% [markdown]
# ### Map

# %% [markdown]
# ## Data munging

# %%
food_tmp=food.copy()

# %%
food=food_tmp.copy()

# %%
food["Address"]=food["Address"].str.strip()

# %%
import re
# casefold
food["DBA Name"]=food["DBA Name"].str.casefold()
food["AKA Name"]=food["AKA Name"].str.casefold()
# remove anything within paranthesis
food["AKA Name"]=food["AKA Name"].apply(lambda x: re.sub(r'\([^)]*\)', '', x ))

# %%
# Let's inspect joint businesses, these have a "/" in their AKA Name
joint=food[["/" in aka for aka in food["AKA Name"]]]["AKA Name"].unique()
joint[0:20]
# Out:
# array(['vienna beef/pizzeria uno ', 'burrito beach/b smooth ',
#        'hvac pub/glacier city frozen yogurt',
#        'dunkin donuts / baskin robbins',
#        "hilton o'hare/andiamo's/caffe mercato",
#        'dunkin donuts/baskin robbins', 'wow bao/t5 m-10',
#        'chop shop/1st ward', 'guyjean/gaijin japanese restaurant',
#        'urban olive/t5 m10', 'xando coffee & bar / cosi sandwich bar',
#        'moody tongue brewing company/the bar at moody tong',
#        'dunkin donut/baskin robbins', 'bp/subway',
#        'cafe integral/ broken shaker', 'cvs/pharmacy #11376',
#        'the chg bear sports bar/grill', 'kfc/taco bell',
#        'swift & sons/cold storage', 'jewel/osco'], dtype=object)

# %%
# Lots of them are in the form "cvs/pharmacy #xxxxx" so we can fix this 
cvs=food[[aka.startswith("cvs") for aka in food["AKA Name"]]]["AKA Name"].index
food.loc[cvs,"AKA Name"]="cvs"

# %%
# remove punctuation
food["DBA Name"]=food["DBA Name"].str.replace(r'[^\w\s]+', '')

food["AKA Name"]=food["AKA Name"].str.replace(r'[^\w\s]+', '')
# Hardcode formatting for food chains
food["AKA Name"]=food["AKA Name"].str.replace("kentucky fried chicken", 'kfc')
food["AKA Name"]=food["AKA Name"].str.replace("mc donalds","mcdonalds")
food["AKA Name"]=food["AKA Name"].str.replace("mcdonalds restaurant","mcdonalds")
food["AKA Name"]=food["AKA Name"].str.replace("dominos pizza","dominos")
food["AKA Name"]=food["AKA Name"].str.replace("subway sandwiches","subway")
food["AKA Name"]=food["AKA Name"].str.replace("chipotle mexican grill","chipotle")
food["AKA Name"]=food["AKA Name"].str.replace("potbelly sandwich works", "potbelly")
food["AKA Name"]=food["AKA Name"].str.replace("potbelly sandwich works llc", "potbelly")
food["AKA Name"]=food["AKA Name"].str.replace("whole foods market","whole foods")
food["AKA Name"]=food["AKA Name"].str.replace("7eleven","7 eleven")
food["AKA Name"]=food["AKA Name"].str.replace("j  j fish","jj fish  chicken")
food["AKA Name"]=food["AKA Name"].str.replace("quiznos sub","quiznos")
food["AKA Name"]=food["AKA Name"].str.replace("starbucks coffee","starbucks")
food["AKA Name"]=food["AKA Name"].str.replace("donutsbaskin","donuts baskin")


food["AKA Name"]=food["AKA Name"].str.title()
food["AKA Name"]=food["AKA Name"].str.replace(" ","")
food["DBA Name"]=food["DBA Name"].str.strip()

# %%
food_tmp1=food.copy()

# %%
food=food_tmp1.copy()

# %%
food['Violations'][4]
# Out:
# '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED | 53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED THE UNISEX RESTROOM TRASH RECEPTACLE NOT COVERED, INSTRUCTED TO PROVIDE COVER.'

# %%
def violation_parsing(food):
    violation_number = []
    violation_title = []
    violation_comment = []
    number_exploded = []
    ids_exploded = []
    title_exploded = []
    comment_exploded = []
    
    for index,row in food.iterrows():
        list_violation= row['Violations'].split(' | ')
        numbers = []
        titles = []
        comments = []
        for vl in list_violation:
            ids_exploded.append(row['Inspection ID'])
            comment_splited = vl.split('- Comments:')
            split_point = comment_splited[0].split('.')
            numbers.append(split_point[0])
            
            number_exploded.append(split_point[0])
            
            titles.append(split_point[1].strip())
            title_exploded.append(split_point[1].strip())
            
            if(len(comment_splited) <= 1):
                comments.append("")
                comment_exploded.append("")
            else:
                comments.append(comment_splited[1].strip())
                comment_exploded.append(comment_splited[1].strip())
            
        violation_number.append(numbers)
        violation_title.append(titles)
        violation_comment.append(comments)
        
    df = pd.DataFrame({"ids": ids_exploded ,"numbers" : number_exploded , "titles" : title_exploded, "comments" : comment_exploded})
    return violation_number, violation_title, violation_comment,df

# %%
food ['Violation numbers'], food ['Violation title'], food ['Violation comments'], violation_exploded = violation_parsing(food)

# %%
violation_exploded[violation_exploded["numbers"]=="70"]
# Out:
#             ids numbers                  titles  \
# 113475  2181892      70  NO SMOKING REGULATIONS
# 115959  2177196      70  NO SMOKING REGULATIONS
# 116758  2176879      70  NO SMOKING REGULATIONS
# 117191  2176737      70  NO SMOKING REGULATIONS
# 117791  2176576      70  NO SMOKING REGULATIONS
# ...         ...     ...                     ...
# 652165    80235      70  NO SMOKING REGULATIONS
# 653499   148212      70  NO SMOKING REGULATIONS
# 655180   150218      70  NO SMOKING REGULATIONS
# 655244    67961      70  NO SMOKING REGULATIONS
# 657044   158248      70  NO SMOKING REGULATIONS
#
#                                                  comments
# 113475  OBSERVED AN ASHTRAY WITH CIGARETTE BUTTS ON A ...
# 115959  NO 'NO SMOKING' SIGNAGE AT ENTRANCE/EXIT TO PR...
# 116758  Observed uniformed employee actively smoking c...
# 117191  Observed 3 cigarette butts on floor of employe...
# 117791  Observed establishment not complying with clea...
# ...                                                   ...
# 652165  Smoking shall be prohibited in all public plac...
# 653499  REQUIRED 'NO SMOKING' SIGNS NOT POSTED AT ENTR...
# 655180  NO REQUIRED 'NO SMOKING' SIGNS POSTED IN PREMI...
# 655244  Smoking shall be prohibited in all public plac...
# 657044  Smoking shall be prohibited in all public plac...
#
# [591 rows x 4 columns]

# %% [markdown]
# This dataframe will be useful for text mining after.

# %% [markdown]
#     -For violation number 1-14 it refers to no critical violations, minor.
#     -For violation number 15-29 it refers to serious violations.
#     -For the rest it refers to critical violations.

# %%
food ['Results'][food ['Violation numbers'].map(lambda x: (len(x) == 1) & (x== ["70"])) ].value_counts()
# Out:
# Pass w/ Conditions    5
# Name: Results, dtype: int64

# %%
food ['Results'][food ['Violation numbers'].map(lambda x: "70" in x )].value_counts()
# Out:
# Fail                  381
# Pass w/ Conditions    164
# Pass                    9
# Name: Results, dtype: int64

# %%
temp = violation_exploded.groupby('numbers').titles.nunique().sort_values(ascending = False)
temp= temp[temp>1]

same_number_different_title = violation_exploded[[number in temp.index for number in violation_exploded['numbers']]].groupby('numbers').titles.unique()

# %%
same_number_different_title.map(lambda x: len(x))
# Out:
# numbers
# 1     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    2
# 19    2
# 2     2
# 20    2
# 21    2
# 22    2
# 23    2
# 24    2
# 25    2
# 26    2
# 27    2
# 28    2
# 29    2
# 3     2
# 30    2
# 31    2
# 32    2
# 33    2
# 34    2
# 35    2
# 36    2
# 37    2
# 38    2
# 39    2
# 4     2
# 40    2
# 41    2
# 42    2
# 43    2
# 44    2
# 45    2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# Name: titles, dtype: int64

# %% [markdown]
# ## From here I want to see if I can do better if I merge first

# %%
license.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 987259 entries, 0 to 987258
# Data columns (total 39 columns):
# ID                                   987259 non-null object
# LICENSE ID                           987259 non-null int64
# ACCOUNT NUMBER                       987259 non-null int64
# SITE NUMBER                          987259 non-null int64
# LEGAL NAME                           987255 non-null object
# DOING BUSINESS AS NAME               987184 non-null object
# ADDRESS                              987259 non-null object
# CITY                                 987256 non-null object
# STATE                                987247 non-null object
# ZIP CODE                             986838 non-null object
# WARD                                 913816 non-null float64
# PRECINCT                             881964 non-null float64
# WARD PRECINCT                        914001 non-null object
# POLICE DISTRICT                      887405 non-null float64
# LICENSE CODE                         987259 non-null int64
# LICENSE DESCRIPTION                  987259 non-null object
# BUSINESS ACTIVITY ID                 454323 non-null object
# BUSINESS ACTIVITY                    454323 non-null object
# LICENSE NUMBER                       987258 non-null float64
# APPLICATION TYPE                     987259 non-null object
# APPLICATION CREATED DATE             229580 non-null object
# APPLICATION REQUIREMENTS COMPLETE    968952 non-null object
# PAYMENT DATE                         965255 non-null object
# CONDITIONAL APPROVAL                 987259 non-null object
# LICENSE TERM START DATE              984575 non-null object
# LICENSE TERM EXPIRATION DATE         987164 non-null object
# LICENSE APPROVED FOR ISSUANCE        938736 non-null object
# DATE ISSUED                          987259 non-null object
# LICENSE STATUS                       987259 non-null object
# LICENSE STATUS CHANGE DATE           67313 non-null object
# SSA                                  256398 non-null float64
# LATITUDE                             910555 non-null float64
# LONGITUDE                            910555 non-null float64
# LOCATION                             910555 non-null object
# Community Areas                      905528 non-null float64
# Historical Wards 2003-2015           905655 non-null float64
# Zip Codes                            910555 non-null object
# Census Tracts                        909616 non-null float64
# Wards                                905528 non-null float64
# dtypes: float64(11), int64(4), object(24)
# memory usage: 293.8+ MB

# %%
# Find all columns with at least one null value
null_cols=np.sum(license.isnull() , axis=0)
null_cols[null_cols==0]
# Out:
# ID                      0
# LICENSE ID              0
# ACCOUNT NUMBER          0
# SITE NUMBER             0
# ADDRESS                 0
# LICENSE CODE            0
# LICENSE DESCRIPTION     0
# APPLICATION TYPE        0
# CONDITIONAL APPROVAL    0
# DATE ISSUED             0
# LICENSE STATUS          0
# dtype: int64

# %%
license["DOING BUSINESS AS NAME"]=license["DOING BUSINESS AS NAME"].str.casefold()
# remove punctiation
license["DOING BUSINESS AS NAME"]=license["DOING BUSINESS AS NAME"].str.replace(r'[^\w\s]+', '')
license["DOING BUSINESS AS NAME"]=license["DOING BUSINESS AS NAME"].str.strip()
license["ADDRESS"]=license["ADDRESS"].str.strip()

# %%
inspections=food.copy()
licenses=license.copy()
# Match based on DBA name and street number
venue_matches = pd.merge(inspections, licenses, left_on=["DBA Name", "Address"], right_on=["DOING BUSINESS AS NAME", "ADDRESS"])

# Match based on license numbers
license_matches = pd.merge(inspections, licenses ,left_on="License #", right_on="LICENSE ID")

# Join matches, reset index, drop duplicates
matches = venue_matches.append(license_matches, sort=False)
matches.reset_index(drop=True, inplace=True)
matches.drop_duplicates(["Inspection ID"], inplace=True)

# %%
matches.shape
# Out:
# (159843, 56)

# %%
food2=data.copy()
food2.head(5)
# Out:
#    Inspection ID                                DBA Name  \
# 0        2320519                       SALAM  RESTAURANT
# 1        2320443                         JORDAN DISCOUNT
# 2        2320451                   PRETTY COOL ICE CREAM
# 3        2320388                          BOMBASTIC CAFE
# 4        2320389  ALL THINGS ARE POSSIBLE FOR KIDS, INC.
#
#                                  AKA Name  License #  \
# 0                        SALAM RESTAURANT  2002822.0
# 1                         JORDAN DISCOUNT  2694525.0
# 2                   PRETTY COOL ICE CREAM  2616833.0
# 3                          BOMBASTIC CAFE  2678198.0
# 4  ALL THINGS ARE POSSIBLE FOR KIDS, INC.  2215965.0
#
#                   Facility Type             Risk                  Address  \
# 0                    Restaurant    Risk 1 (High)  4634-4636 N KEDZIE AVE
# 1                 Grocery Store     Risk 3 (Low)       5254 W MADISON ST
# 2                    Restaurant    Risk 1 (High)   2353 N CALIFORNIA AVE
# 3                    Restaurant  Risk 2 (Medium)    3732 N SOUTHPORT AVE
# 4  Children's Services Facility    Risk 1 (High)      4014 W CHICAGO AVE
#
#       City State      Zip  ... Results  \
# 0  CHICAGO    IL  60625.0  ...    Pass
# 1  CHICAGO    IL  60644.0  ...    Pass
# 2  CHICAGO    IL  60647.0  ...    Pass
# 3  CHICAGO    IL  60613.0  ...    Fail
# 4  CHICAGO    IL  60651.0  ...    Pass
#
#                                           Violations   Latitude  Longitude  \
# 0                                                NaN  41.965719 -87.708538
# 1                                                NaN  41.880455 -87.757290
# 2  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.924363 -87.697255
# 3  53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  41.949883 -87.664242
# 4  54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILI...  41.895468 -87.726665
#
#                                    Location  Historical Wards 2003-2015  \
# 0  (-87.70853756167853, 41.965719017423005)                         NaN
# 1   (-87.75728976536573, 41.88045497430518)                         NaN
# 2   (-87.69725539567338, 41.92436282156778)                         NaN
# 3    (-87.6642417785868, 41.94988264936109)                         NaN
# 4    (-87.7266648149535, 41.89546788877342)                         NaN
#
#   Zip Codes  Community Areas  Census Tracts  Wards
# 0       NaN              NaN            NaN    NaN
# 1       NaN              NaN            NaN    NaN
# 2       NaN              NaN            NaN    NaN
# 3       NaN              NaN            NaN    NaN
# 4       NaN              NaN            NaN    NaN
#
# [5 rows x 22 columns]

# %%
fl=pd.merge(food2, license, how="left",left_on="License #", right_on="LICENSE ID")
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194904 entries, 0 to 194903
# Data columns (total 61 columns):
# Inspection ID                        194904 non-null int64
# DBA Name                             194904 non-null object
# AKA Name                             192453 non-null object
# License #                            194887 non-null float64
# Facility Type                        190128 non-null object
# Risk                                 194832 non-null object
# Address                              194904 non-null object
# City                                 194766 non-null object
# State                                194862 non-null object
# Zip                                  194854 non-null float64
# Inspection Date                      194904 non-null object
# Inspection Type                      194903 non-null object
# Results                              194904 non-null object
# Violations                           143211 non-null object
# Latitude                             194222 non-null float64
# Longitude                            194222 non-null float64
# Location                             194222 non-null object
# Historical Wards 2003-2015_x         0 non-null float64
# Zip Codes_x                          0 non-null float64
# Community Areas_x                    0 non-null float64
# Census Tracts_x                      0 non-null float64
# Wards_x                              0 non-null float64
# ID                                   143326 non-null object
# LICENSE ID                           143326 non-null float64
# ACCOUNT NUMBER                       143326 non-null float64
# SITE NUMBER                          143326 non-null float64
# LEGAL NAME                           143326 non-null object
# DOING BUSINESS AS NAME               143326 non-null object
# ADDRESS                              143326 non-null object
# CITY                                 143326 non-null object
# STATE                                143326 non-null object
# ZIP CODE                             143168 non-null object
# WARD                                 142943 non-null float64
# PRECINCT                             134427 non-null float64
# WARD PRECINCT                        143000 non-null object
# POLICE DISTRICT                      134991 non-null float64
# LICENSE CODE                         143326 non-null float64
# LICENSE DESCRIPTION                  143326 non-null object
# BUSINESS ACTIVITY ID                 137540 non-null object
# BUSINESS ACTIVITY                    137540 non-null object
# LICENSE NUMBER                       143326 non-null float64
# APPLICATION TYPE                     143326 non-null object
# APPLICATION CREATED DATE             125870 non-null object
# APPLICATION REQUIREMENTS COMPLETE    138584 non-null object
# PAYMENT DATE                         137325 non-null object
# CONDITIONAL APPROVAL                 143326 non-null object
# LICENSE TERM START DATE              142754 non-null object
# LICENSE TERM EXPIRATION DATE         143310 non-null object
# LICENSE APPROVED FOR ISSUANCE        138163 non-null object
# DATE ISSUED                          143326 non-null object
# LICENSE STATUS                       143326 non-null object
# LICENSE STATUS CHANGE DATE           5754 non-null object
# SSA                                  46927 non-null float64
# LATITUDE                             141660 non-null float64
# LONGITUDE                            141660 non-null float64
# LOCATION                             141660 non-null object
# Community Areas_y                    140063 non-null float64
# Historical Wards 2003-2015_y         140063 non-null float64
# Zip Codes_y                          141660 non-null object
# Census Tracts_y                      141648 non-null float64
# Wards_y                              140063 non-null float64
# dtypes: float64(24), int64(1), object(36)
# memory usage: 92.2+ MB

# %%
fl[(fl["Latitude"].isnull())&~(fl["LATITUDE"].isnull())]
# We can impute the values
# Out:
#         Inspection ID                        DBA Name  \
# 970           2290928  SCHWAB REHAB HOSPITAL&CARE NET
# 2686          2229372                  RICE THAI CAFE
# 3442          2181528            MAGO GRILL & CANTINA
# 5630          2078297                      CHARTWELLS
# 7855          1966841                       CAFFE ROM
# ...               ...                             ...
# 193218          98355       BAGONG TAON ORIENTAL MART
# 193221          98335       BAGONG TAON ORIENTAL MART
# 193869         158253                 ARGENTINA FOODS
# 194066          67738          MICHAEL'S ON MAIN CAFE
# 194493         158272                 ARGENTINA FOODS
#
#                               AKA Name  License #        Facility Type  \
# 970     SCHWAB REHAB HOSPITAL&CARE NET  2205586.0             Hospital
# 2686                    RICE THAI CAFE  2589016.0                  NaN
# 3442              MAGO GRILL & CANTINA  2423995.0           Restaurant
# 5630              MANSUETO HIGH SCHOOL  2549059.0  HIGH SCHOOL KITCHEN
# 7855                         CAFFE ROM  1847943.0           Restaurant
# ...                                ...        ...                  ...
# 193218       BAGONG TAON ORIENTAL MART  2014336.0        Grocery Store
# 193221       BAGONG TAON ORIENTAL MART  2014336.0        Grocery Store
# 193869                 ARGENTINA FOODS  2009367.0        Grocery Store
# 194066          MICHAEL'S ON MAIN CAFE  2008948.0           Restaurant
# 194493                 ARGENTINA FOODS  2009367.0        Grocery Store
#
#                    Risk                    Address     City State      Zip  \
# 970       Risk 1 (High)     1401 S CALIFORNIA AVE   CHICAGO    IL  60608.0
# 2686                NaN      211`7 W FARRAGUT AVE   CHICAGO    IL  60625.0
# 3442      Risk 1 (High)          1010 S DELANO CT   CHICAGO    IL  60605.0
# 5630      Risk 1 (High)          2911 W W 47TH ST   CHICAGO    IL  60632.0
# 7855    Risk 2 (Medium)            400 E WATER ST   CHICAGO    IL  60601.0
# ...                 ...                        ...      ...   ...      ...
# 193218     Risk 3 (Low)  3549 W IRVING PK. RD. RD   CHICAGO    IL  60618.0
# 193221     Risk 3 (Low)  3549 W IRVING PK. RD. RD   CHICAGO    IL  60618.0
# 193869  Risk 2 (Medium)           4500 S WOODS ST   CHICAGO    IL  60609.0
# 194066    Risk 1 (High)      8750 W BRYN WAWR AVE   CHICAGO    IL  60631.0
# 194493  Risk 2 (Medium)           4500 S WOODS ST   CHICAGO    IL  60609.0
#
#         ... LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 970     ...                        NaN   NaN  41.862520 -87.695645
# 2686    ...                        NaN  54.0  42.004881 -87.661011
# 3442    ...                        NaN   NaN  41.869464 -87.632854
# 5630    ...                        NaN   NaN  41.808122 -87.697074
# 7855    ...                        NaN   NaN  41.886634 -87.617413
# ...     ...                        ...   ...        ...        ...
# 193218  ...                        NaN   NaN  41.953683 -87.717355
# 193221  ...                        NaN   NaN  41.953683 -87.717355
# 193869  ...                        NaN   NaN  41.812105 -87.670072
# 194066  ...                        NaN   NaN  41.981063 -87.845674
# 194493  ...                        NaN   NaN  41.812105 -87.670072
#
#                                         LOCATION  Community Areas_y  \
# 970      (41.86251966597367, -87.69564453384106)               30.0
# 2686     (42.00488091989163, -87.66101071134382)               10.0
# 3442     (41.86946441129826, -87.63285448774887)               38.0
# 5630     (41.80812169070144, -87.69707374951754)               55.0
# 7855    (41.886633519398195, -87.61741342043217)               38.0
# ...                                          ...                ...
# 193218    (41.95368324175896, -87.7173554572528)               16.0
# 193221    (41.95368324175896, -87.7173554572528)               16.0
# 193869   (41.81210515297724, -87.67007183351623)               59.0
# 194066   (41.98106319707633, -87.84567441591551)               75.0
# 194493   (41.81210515297724, -87.67007183351623)               59.0
#
#        Historical Wards 2003-2015_y  Zip Codes_y  Census Tracts_y  Wards_y
# 970                            11.0       14,920             16.0     23.0
# 2686                            3.0       21,853             47.0      5.0
# 3442                           48.0       14,917             12.0     26.0
# 5630                           49.0       22,248             85.0      8.0
# 7855                           22.0       14,309            580.0     36.0
# ...                             ...          ...              ...      ...
# 193218                          2.0       21,538            325.0     12.0
# 193221                          2.0       21,538            325.0     12.0
# 193869                         53.0       14,924            706.0      3.0
# 194066                         34.0       22,243             64.0     29.0
# 194493                         53.0       14,924            706.0      3.0
#
# [121 rows x 61 columns]

# %%
null_cols=np.sum(license.isnull() , axis=0)
null_cols[null_cols>0]
# Out:
# LEGAL NAME                                4
# DOING BUSINESS AS NAME                   75
# CITY                                      3
# STATE                                    12
# ZIP CODE                                421
# WARD                                  73443
# PRECINCT                             105295
# WARD PRECINCT                         73258
# POLICE DISTRICT                       99854
# BUSINESS ACTIVITY ID                 532936
# BUSINESS ACTIVITY                    532936
# LICENSE NUMBER                            1
# APPLICATION CREATED DATE             757679
# APPLICATION REQUIREMENTS COMPLETE     18307
# PAYMENT DATE                          22004
# LICENSE TERM START DATE                2684
# LICENSE TERM EXPIRATION DATE             95
# LICENSE APPROVED FOR ISSUANCE         48523
# LICENSE STATUS CHANGE DATE           919946
# SSA                                  730861
# LATITUDE                              76704
# LONGITUDE                             76704
# LOCATION                              76704
# Community Areas                       81731
# Historical Wards 2003-2015            81604
# Zip Codes                             76704
# Census Tracts                         77643
# Wards                                 81731
# dtype: int64

# %%
fl[fl["LICENSE ID"].isnull()]
# Out:
#         Inspection ID                          DBA Name  \
# 1             2320443                   JORDAN DISCOUNT
# 3             2320388                    BOMBASTIC CAFE
# 5             2320364  FIREWATER SALOON MOUNT GREENWOOD
# 6             2320354                  AVLI RIVER NORTH
# 7             2320439                TAQUERIA LA CIUDAD
# ...               ...                               ...
# 194891         124352          RESURRECTION LIFE CENTER
# 194895         164363                TOWN FOOD & LIQUOR
# 194898         134239              BORNIQUEN RESTAURANT
# 194901         164336                             White
# 194903         176291                JOE'S BARBQUE, INC
#
#                                 AKA Name  License #         Facility Type  \
# 1                        JORDAN DISCOUNT  2694525.0         Grocery Store
# 3                         BOMBASTIC CAFE  2678198.0            Restaurant
# 5       FIREWATER SALOON MOUNT GREENWOOD    15956.0            Restaurant
# 6                       AVLI RIVER NORTH  2683658.0            Restaurant
# 7                     TAQUERIA LA CIUDAD  2631346.0  Mobile Food Preparer
# ...                                  ...        ...                   ...
# 194891          RESURRECTION LIFE CENTER    57358.0        Long Term Care
# 194895                TOWN FOOD & LIQUOR    13826.0         Grocery Store
# 194898              BORNIQUEN RESTAURANT    32942.0            Restaurant
# 194901                             White    26431.0                School
# 194903                     JOE'S BARBQUE    18234.0            Restaurant
#
#                    Risk                    Address     City State      Zip  \
# 1          Risk 3 (Low)         5254 W MADISON ST   CHICAGO    IL  60644.0
# 3       Risk 2 (Medium)      3732 N SOUTHPORT AVE   CHICAGO    IL  60613.0
# 5         Risk 1 (High)           3908 W 111TH ST   CHICAGO    IL  60655.0
# 6          Risk 3 (Low)        700-702 N WELLS ST   CHICAGO    IL  60654.0
# 7       Risk 2 (Medium)     3233-3237 W Cermak RD   CHICAGO    IL  60623.0
# ...                 ...                        ...      ...   ...      ...
# 194891    Risk 1 (High)        7435 W TALCOTT AVE   CHICAGO    IL  60631.0
# 194895     Risk 3 (Low)            1813 W 63RD ST   CHICAGO    IL  60636.0
# 194898    Risk 1 (High)     1720 N CALIFORNIA AVE   CHICAGO    IL  60647.0
# 194901    Risk 1 (High)  1136 W 122nd St (12200S)   CHICAGO    IL  60643.0
# 194903    Risk 1 (High)         4900 W MADISON ST   CHICAGO    IL  60644.0
#
#         ... LICENSE STATUS CHANGE DATE SSA LATITUDE LONGITUDE  LOCATION  \
# 1       ...                        NaN NaN      NaN       NaN       NaN
# 3       ...                        NaN NaN      NaN       NaN       NaN
# 5       ...                        NaN NaN      NaN       NaN       NaN
# 6       ...                        NaN NaN      NaN       NaN       NaN
# 7       ...                        NaN NaN      NaN       NaN       NaN
# ...     ...                        ...  ..      ...       ...       ...
# 194891  ...                        NaN NaN      NaN       NaN       NaN
# 194895  ...                        NaN NaN      NaN       NaN       NaN
# 194898  ...                        NaN NaN      NaN       NaN       NaN
# 194901  ...                        NaN NaN      NaN       NaN       NaN
# 194903  ...                        NaN NaN      NaN       NaN       NaN
#
#         Community Areas_y Historical Wards 2003-2015_y  Zip Codes_y  \
# 1                     NaN                          NaN          NaN
# 3                     NaN                          NaN          NaN
# 5                     NaN                          NaN          NaN
# 6                     NaN                          NaN          NaN
# 7                     NaN                          NaN          NaN
# ...                   ...                          ...          ...
# 194891                NaN                          NaN          NaN
# 194895                NaN                          NaN          NaN
# 194898                NaN                          NaN          NaN
# 194901                NaN                          NaN          NaN
# 194903                NaN                          NaN          NaN
#
#         Census Tracts_y  Wards_y
# 1                   NaN      NaN
# 3                   NaN      NaN
# 5                   NaN      NaN
# 6                   NaN      NaN
# 7                   NaN      NaN
# ...                 ...      ...
# 194891              NaN      NaN
# 194895              NaN      NaN
# 194898              NaN      NaN
# 194901              NaN      NaN
# 194903              NaN      NaN
#
# [51578 rows x 61 columns]

# %%
license["BUSINESS ACTIVITY"].unique()
# Out:
# array([nan, 'Retail Sales of Perishable Foods',
#        'Catering of Liquor From a Business Not Located In Chicago', ...,
#        'Provide Animal Boarding Services | Provide Animal Day Care Services | Retail Sales of General Merchandise',
#        "Retail Sales of General Merchandise | Buying and Reselling of Used Children's Products",
#        'Rental of Musical Instruments | Instruction in Music for Both Children and Adults (Less Than 40% Children)'],
#       dtype=object)

# %%
fl[(fl["Zip"].isnull()) & (~fl["ZIP CODE"].isnull())]
# Out:
#         Inspection ID                                     DBA Name  \
# 9453          1763245                   EAT N RUN CHICKEN AND FISH
# 13423         1447538                           I DREAM OF FALAFEL
# 16296         1106878                    FILIPINO AMERICAN COUNCIL
# 22512          598237   SPORT SERVICE SOLDIER FIELD/SUITE PANTRY D
# 23176          525238                        THE LUNCH MACHINE INC
# 23288          525226                        THE LUNCH MACHINE INC
# 23338          525214                        THE LUNCH MACHINE INC
# 24022          335363                TISH'S TINY TOWN FOR TOTS CHI
# 24191          414066                              OSCO DRUG #3632
# 42696         2222692                        LEO'S FOOD AND LIQUOR
# 45494         2200428                        LEO'S FOOD AND LIQUOR
# 73116         1977089                                       SUBWAY
# 99921         1562130              PARKWEST LIQUORS AND SMOKE SHOP
# 100953        1375435                        N AND A FOOD MART INC
# 103290        1566296              PARKWEST LIQUORS AND SMOKE SHOP
# 107986        1523196                            BURGER KING #1310
# 108206        1538026               FOSTER GROCERY AND DOLLAR PLUS
# 126291        1396156                           THINK SIMPLE FOODS
# 129348        1228307                              MCCORNICK PLACE
# 130760        1396011                           THINK SIMPLE FOODS
# 131894        1228306                              MCCORMICK PLACE
# 133170        1115029                  SPORT SERVICE SOLDIER FIELD
# 136713        1115030  SPORT SERVICE SOLDIER FIELD /SUITE PANTRY C
# 137268        1361108   SPORT SERVICE SOLDIER FIELD/SUITE PANTRY D
# 144378        1114725                            BURGER KING #1310
# 161858         679984                              OSCO DRUG #3632
# 172727         598235                  SPORT SERVICE SOLDIER FIELD
# 172771         598236  SPORT SERVICE SOLDIER FIELD /SUITE PANTRY C
# 176288         525253                        THE LUNCH MACHINE INC
# 178883         391371                      GOLDEN HOUSE RESTAURANT
# 178942         525228                        THE LUNCH MACHINE INC
# 180901         525229                      GOLDEN HOUSE RESTAURANT
# 181128         413369                           I DREAM OF FALAFEL
# 181135         419311                              OSCO DRUG #3632
# 181351         419250                              OSCO DRUG #3632
# 193238          63277                                SUN FOOD MART
# 194233          67807                                SUN FOOD MART
#
#                              AKA Name  License #          Facility Type  \
# 9453       EAT N RUN CHICKEN AND FISH  2442868.0             Restaurant
# 13423              I DREAM OF FALAFEL  2032750.0                    NaN
# 16296                    RIZAL CENTER  2225427.0           Golden Diner
# 22512                  SUITE PANTRY D  1354323.0             Restaurant
# 23176                             NaN  2079077.0  Mobile Food Dispenser
# 23288                             NaN  2079077.0  Mobile Food Dispenser
# 23338                             NaN  2079077.0  Mobile Food Dispenser
# 24022   TISH'S TINY TOWN FOR TOTS CHI  1887746.0                    NaN
# 24191                 OSCO DRUG #3632  2037183.0                 Liquor
# 42696                    LEO'S LIQUOR  2535068.0                 Liquor
# 45494                    LEO'S LIQUOR  2535068.0                 Liquor
# 73116                             NaN  1991157.0             Restaurant
# 99921                PARKWEST LIQUORS  2354157.0                 Liquor
# 100953                            NaN  1980101.0          Grocery Store
# 103290               PARKWEST LIQUORS  2354157.0                 Liquor
# 107986                    BURGER KING  2232344.0             Restaurant
# 108206                            NaN  1992096.0          Grocery Store
# 126291                            NaN  2308286.0             Restaurant
# 129348     WEST WAREHOUSE / WBI - 122  1932251.0             Restaurant
# 130760                            NaN  2308286.0             Restaurant
# 131894        KIOSK HOLDING UNIT AREA  1932251.0             Restaurant
# 133170                 SUITE PANTRY B  1354323.0             Restaurant
# 136713                 SUITE PANTRY C  1354323.0             Restaurant
# 137268                 SUITE PANTRY D  1354323.0             Restaurant
# 144378                    BURGER KING  2232344.0             Restaurant
# 161858                OSCO DRUG #3632  2137471.0                 Liquor
# 172727                 SUITE PANTRY B  1354323.0             Restaurant
# 172771                 SUITE PANTRY C  1354323.0             Restaurant
# 176288                            NaN  2079077.0  Mobile Food Dispenser
# 178883                            NaN  1443483.0             Restaurant
# 178942                            NaN  2079077.0  Mobile Food Dispenser
# 180901                            NaN  1443483.0             Restaurant
# 181128             I DREAM OF FALAFEL  2032750.0                    NaN
# 181135                OSCO DRUG #3632  2037183.0                 Liquor
# 181351                OSCO DRUG #3632  2037183.0                 Liquor
# 193238                  SUN FOOD MART  2009479.0          Grocery Store
# 194233                  SUN FOOD MART  2009479.0          Grocery Store
#
#                    Risk                         Address City State  Zip  ...  \
# 9453      Risk 1 (High)                                  NaN    IL  NaN  ...
# 13423     Risk 1 (High)              329 S FRANKLIN ST   NaN    IL  NaN  ...
# 16296     Risk 1 (High)  1332 W DRIVING PARK ROAD BSMT   NaN    IL  NaN  ...
# 22512   Risk 2 (Medium)       1410 S MUSEUM CAMPUS DR.   NaN    IL  NaN  ...
# 23176   Risk 2 (Medium)              1319 W WILSON AVE   NaN    IL  NaN  ...
# 23288   Risk 2 (Medium)              1319 W WILSON AVE   NaN    IL  NaN  ...
# 23338   Risk 2 (Medium)              1319 W WILSON AVE   NaN    IL  NaN  ...
# 24022     Risk 1 (High)                 2301 E 79TH ST   NaN    IL  NaN  ...
# 24191      Risk 3 (Low)           3630 N SOUTHPORT AVE   NaN    IL  NaN  ...
# 42696      Risk 3 (Low)            4471 W LAWRENCE AVE   NaN    IL  NaN  ...
# 45494      Risk 3 (Low)            4471 W LAWRENCE AVE   NaN    IL  NaN  ...
# 73116   Risk 2 (Medium)           2184 N CLYBOURN BLDG   NaN    IL  NaN  ...
# 99921      Risk 3 (Low)             2570 N LINCOLN AVE   NaN    IL  NaN  ...
# 100953     Risk 3 (Low)              433 E 79TH STREET   NaN    IL  NaN  ...
# 103290     Risk 3 (Low)             2570 N LINCOLN AVE   NaN    IL  NaN  ...
# 107986  Risk 2 (Medium)       2320-2322 S MICHIGAN AVE   NaN    IL  NaN  ...
# 108206     Risk 3 (Low)              3358 W FOSTER AVE   NaN    IL  NaN  ...
# 126291  Risk 2 (Medium)              141 W CHICAGO AVE   NaN    IL  NaN  ...
# 129348    Risk 1 (High)                 2301 S INDIANA   NaN    IL  NaN  ...
# 130760  Risk 2 (Medium)              141 W CHICAGO AVE   NaN    IL  NaN  ...
# 131894    Risk 1 (High)            2301 S INDIANA AVE.   NaN    IL  NaN  ...
# 133170  Risk 2 (Medium)       1410 S MUSEUM CAMPUS DR.   NaN    IL  NaN  ...
# 136713  Risk 2 (Medium)           1410 S MUSEUM CAMPUS   NaN    IL  NaN  ...
# 137268  Risk 2 (Medium)       1410 S MUSEUM CAMPUS DR.   NaN    IL  NaN  ...
# 144378  Risk 2 (Medium)       2320-2322 S MICHIGAN AVE   NaN    IL  NaN  ...
# 161858     Risk 3 (Low)           3630 N SOUTHPORT AVE   NaN    IL  NaN  ...
# 172727  Risk 2 (Medium)       1410 S MUSEUM CAMPUS DR.   NaN    IL  NaN  ...
# 172771  Risk 2 (Medium)           1410 S MUSEUM CAMPUS   NaN    IL  NaN  ...
# 176288  Risk 2 (Medium)              1319 W WILSON AVE   NaN    IL  NaN  ...
# 178883    Risk 1 (High)           4742-44 N RACINE AVE   NaN    IL  NaN  ...
# 178942  Risk 2 (Medium)              1319 W WILSON AVE   NaN    IL  NaN  ...
# 180901    Risk 1 (High)           4742-44 N RACINE AVE   NaN    IL  NaN  ...
# 181128    Risk 1 (High)              329 S FRANKLIN ST   NaN    IL  NaN  ...
# 181135     Risk 3 (Low)           3630 N SOUTHPORT AVE   NaN    IL  NaN  ...
# 181351     Risk 3 (Low)           3630 N SOUTHPORT AVE   NaN    IL  NaN  ...
# 193238     Risk 3 (Low)               3601 W CERMAK RD   NaN    IL  NaN  ...
# 194233     Risk 3 (Low)               3601 W CERMAK RD   NaN    IL  NaN  ...
#
#        LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 9453                          NaN  69.0  41.743903 -87.663129
# 13423                         NaN   NaN  41.877351 -87.635043
# 16296                         NaN  33.0  41.909454 -87.675796
# 22512                         NaN   NaN  41.862628 -87.615031
# 23176                  12/29/2012  34.0  41.965212 -87.663260
# 23288                  12/29/2012  34.0  41.965212 -87.663260
# 23338                  12/29/2012  34.0  41.965212 -87.663260
# 24022                         NaN  49.0  41.751592 -87.568606
# 24191                         NaN  27.0  41.948005 -87.664186
# 42696                         NaN   NaN  41.967993 -87.740726
# 45494                         NaN   NaN  41.967993 -87.740726
# 73116                         NaN   NaN  41.921186 -87.664014
# 99921                         NaN  35.0  41.928597 -87.653388
# 100953                        NaN  51.0  41.751030 -87.613649
# 103290                        NaN  35.0  41.928597 -87.653388
# 107986                        NaN   NaN  41.850454 -87.623891
# 108206                        NaN   NaN  41.975801 -87.713499
# 126291                        NaN   NaN  41.896504 -87.632784
# 129348                        NaN   NaN  41.851047 -87.622093
# 130760                        NaN   NaN  41.896504 -87.632784
# 131894                        NaN   NaN  41.851047 -87.622093
# 133170                        NaN   NaN  41.862628 -87.615031
# 136713                        NaN   NaN  41.862628 -87.615031
# 137268                        NaN   NaN  41.862628 -87.615031
# 144378                        NaN   NaN  41.850454 -87.623891
# 161858                        NaN  27.0  41.948005 -87.664186
# 172727                        NaN   NaN  41.862628 -87.615031
# 172771                        NaN   NaN  41.862628 -87.615031
# 176288                 12/29/2012  34.0  41.965212 -87.663260
# 178883                        NaN  34.0  41.968491 -87.659816
# 178942                 12/29/2012  34.0  41.965212 -87.663260
# 180901                        NaN  34.0  41.968491 -87.659816
# 181128                        NaN   NaN  41.877351 -87.635043
# 181135                        NaN  27.0  41.948005 -87.664186
# 181351                        NaN  27.0  41.948005 -87.664186
# 193238                        NaN   NaN  41.851553 -87.715059
# 194233                        NaN   NaN  41.851553 -87.715059
#
#                                         LOCATION  Community Areas_y  \
# 9453     (41.743903369579925, -87.6631288234479)               70.0
# 13423    (41.87735119229724, -87.63504276859136)               38.0
# 16296      (41.9094539015706, -87.6757962173346)               25.0
# 22512   (41.862628294037634, -87.61503109411332)               34.0
# 23176    (41.96521193313759, -87.66326005651248)               31.0
# 23288    (41.96521193313759, -87.66326005651248)               31.0
# 23338    (41.96521193313759, -87.66326005651248)               31.0
# 24022     (41.7515920243175, -87.56860603613539)               42.0
# 24191   (41.948004550829744, -87.66418623070139)               57.0
# 42696    (41.96799335620968, -87.74072634914224)               16.0
# 45494    (41.96799335620968, -87.74072634914224)               16.0
# 73116     (41.92118550519079, -87.6640136808923)               68.0
# 99921    (41.92859664532255, -87.65338817338453)               68.0
# 100953   (41.75103049992091, -87.61364868855419)               40.0
# 103290   (41.92859664532255, -87.65338817338453)               68.0
# 107986  (41.850453739981155, -87.62389126353149)               34.0
# 108206   (41.97580062815588, -87.71349867231145)               13.0
# 126291    (41.89650357363852, -87.6327844082446)               37.0
# 129348   (41.85104667463312, -87.62209308455373)               34.0
# 130760    (41.89650357363852, -87.6327844082446)               37.0
# 131894   (41.85104667463312, -87.62209308455373)               34.0
# 133170  (41.862628294037634, -87.61503109411332)               34.0
# 136713  (41.862628294037634, -87.61503109411332)               34.0
# 137268  (41.862628294037634, -87.61503109411332)               34.0
# 144378  (41.850453739981155, -87.62389126353149)               34.0
# 161858  (41.948004550829744, -87.66418623070139)               57.0
# 172727  (41.862628294037634, -87.61503109411332)               34.0
# 172771  (41.862628294037634, -87.61503109411332)               34.0
# 176288   (41.96521193313759, -87.66326005651248)               31.0
# 178883     (41.968490719713, -87.65981645066375)               31.0
# 178942   (41.96521193313759, -87.66326005651248)               31.0
# 180901     (41.968490719713, -87.65981645066375)               31.0
# 181128   (41.87735119229724, -87.63504276859136)               38.0
# 181135  (41.948004550829744, -87.66418623070139)               57.0
# 181351  (41.948004550829744, -87.66418623070139)               57.0
# 193238     (41.85155346052472, -87.715059286164)               32.0
# 194233     (41.85155346052472, -87.715059286164)               32.0
#
#        Historical Wards 2003-2015_y  Zip Codes_y  Census Tracts_y  Wards_y
# 9453                           18.0       21,554            575.0     13.0
# 13423                          48.0       14,914             92.0     36.0
# 16296                          24.0       21,560            482.0     41.0
# 22512                          48.0       14,913            374.0     10.0
# 23176                          37.0       22,616            611.0     39.0
# 23288                          37.0       22,616            611.0     39.0
# 23338                          37.0       22,616            611.0     39.0
# 24022                          43.0       21,202            507.0     37.0
# 24191                          38.0       21,186            724.0     25.0
# 42696                          20.0       21,869            362.0     38.0
# 45494                          20.0       21,869            362.0     38.0
# 73116                          16.0       21,190            210.0     11.0
# 99921                          51.0       21,190            769.0     34.0
# 100953                         31.0       21,546             11.0     32.0
# 103290                         51.0       21,190            769.0     34.0
# 107986                         48.0       21,194            193.0      9.0
# 108206                         28.0       21,849            167.0     38.0
# 126291                         22.0        4,446            670.0     11.0
# 129348                         48.0       21,194            193.0     10.0
# 130760                         22.0        4,446            670.0     11.0
# 131894                         48.0       21,194            193.0     10.0
# 133170                         48.0       14,913            374.0     10.0
# 136713                         48.0       14,913            374.0     10.0
# 137268                         48.0       14,913            374.0     10.0
# 144378                         48.0       21,194            193.0      9.0
# 161858                         38.0       21,186            724.0     25.0
# 172727                         48.0       14,913            374.0     10.0
# 172771                         48.0       14,913            374.0     10.0
# 176288                         37.0       22,616            611.0     39.0
# 178883                         37.0       22,616            611.0     39.0
# 178942                         37.0       22,616            611.0     39.0
# 180901                         37.0       22,616            611.0     39.0
# 181128                         48.0       14,914             92.0     36.0
# 181135                         38.0       21,186            724.0     25.0
# 181351                         38.0       21,186            724.0     25.0
# 193238                         14.0       21,569            754.0     28.0
# 194233                         14.0       21,569            754.0     28.0
#
# [37 rows x 61 columns]

# %%
license[["LICENSE TERM START DATE","BUSINESS ACTIVITY","LICENSE TERM EXPIRATION DATE"]].sample(5)
# Out:
#        LICENSE TERM START DATE  \
# 745300              06/16/2014
# 374403              08/16/2005
# 48724               03/01/2005
# 920982              11/16/2002
# 254244              11/16/2006
#
#                                         BUSINESS ACTIVITY  \
# 745300  Preparation of Food and Dining on Premise With...
# 374403                                                NaN
# 48724                                                 NaN
# 920982                                                NaN
# 254244                                                NaN
#
#        LICENSE TERM EXPIRATION DATE
# 745300                   07/15/2016
# 374403                   08/15/2006
# 48724                    02/15/2006
# 920982                   11/15/2003
# 254244                   11/15/2007

# %%
license["BUSINESS ACTIVITY"].value_counts()
# Out:
# Retail Sales of Perishable Foods                                                                                                                                                                                                                   128482
# Retail Sale of Tobacco                                                                                                                                                                                                                              40514
# Consumption of Liquor on Premises                                                                                                                                                                                                                   30570
# Tavern - Consumption of Liquor on Premise                                                                                                                                                                                                           16782
# Retail Sales of Packaged Liquor                                                                                                                                                                                                                     14105
#                                                                                                                                                                                                                                                     ...
# Home Repair Services (Home Occ) | Interior Design / Consulting (Home Occ) | Snow Removal Service (Home Occ) | Landscaping (Home Occ) | Residential Remodeling and Repair (Home Occ) | Flooring and Window Install, Repair or Replace (Home Occ)         1
# Retail Sales of General Merchandise and Non-Perishable Food | Retail Sales of Appliances                                                                                                                                                                1
# Miscellaneous Commercial Services | Tax Preparation Services | Administrative Commercial Office | Immigration Services                                                                                                                                  1
# Retail Sales of General Merchandise | Provide Full Body Massage Services | Hair Services | Skincare Services                                                                                                                                            1
# Clothing Alterations | Laundry Service | Dry Cleaning - Plant On Premises | Dry Cleaning - Drop Off Location                                                                                                                                            1
# Name: BUSINESS ACTIVITY, Length: 4643, dtype: int64

# %%
#### For now, license database can be used to impute location and zipcode. Do we really need it ?
#### When merged on License ID, 50K of the 200K in food are not matched, should we focus only on the rest?
#### Then we can use business activity and License date to classify by activity and run time series
#### (e.g frequency )

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Food chains

# %%
food[food["DBA Name"]=="subway"]["AKA Name"].unique()
# Out:
# array(['subway'], dtype=object)

# %%
food[food["AKA Name"]=="subway"]["DBA Name"].unique()
# Out:
# array(['subway', 'subway 24879', 'subway sandwiches', 'subway  38326',
#        'wzumba inc', 'subway 26199', 'subway 10266', 'subway store 30969',
#        'subway 44541', 'subway  jay shree inc', 'subway 51581',
#        'subway 50886', 'subway sandwich shop',
#        'subway  26817309 w monroe', 'subway restaurant',
#        'subway restaurant 35406', 'subway 25073', 'subway 24379',
#        'subway sandwich', 'subway sandwiches  salads', 'subway 7709',
#        'subway 65029', 'subway sandwiches and salad', 'subway 3634',
#        'sub way', 'subway  26771', 'subway 14641', 'subway 4267',
#        'subway sandwiches 22222', 'subway at norwegian american hospital',
#        'subway sandwich  salad', 'subway sandwiches 27143',
#        'subway 25064', 'lincoln ave subway', 'subway sandwich  salads',
#        'subway sandwiches  salad', 'subway subs and salads',
#        'sandwich  salad', 'subway sandwich and salads', 'subwaysandwich',
#        'subway sanwich shop', 'subway store   25458', 'ck subway',
#        'subway 275', 'subway 1121', 'subway  7659', 'subway  5183',
#        'subway  tcby', 'suwbay', 'tng enterprises inc',
#        'the great state fare', 'subway sandwiches and salads',
#        'skyhigh101'], dtype=object)

# %%
food[food["AKA Name"]=="mcdonalds"]["DBA Name"].unique()
# Out:
# array(['mcdonalds 4308', 'mcdonalds', 'mc donalds',
#        'canady enterprises corp x', 'mcdonalds 6113',
#        'mcdonalds restaurants', 'mcdonalds 25088', 'mcdonalds restaurant',
#        'mc donalds 3901', 'mc donalds restaurant', 'mcdonalds 335',
#        'mcdonalds 788', 'mcdonalds 4305', 'mcdonalds  29307',
#        'mcdonalds 26371', 'mcdonaldss restaurants', 'mcdonalds 812',
#        'pma mcd inc', 'mcdonald', 'mcdonalds 38631', 'karavites rest inc',
#        'mcdonalds restaurant  14173', 'mcdonalds 5471', 'mcdonalds 10720',
#        'hale family mcdonalds', 'mc donalds 11559',
#        'hale family mc donalds', 'jetbox with dunkin donuts',
#        'mcdonalds 6491', 'mc donalds 6039', 'mc donalds 5697',
#        'mcdonalds rest of ill inc'], dtype=object)

# %%
food[food["DBA Name"]=="mcdonalds"]["AKA Name"].unique()
# Out:
# array(['mcdonalds', 'mcdonalds express'], dtype=object)

# %% [markdown]
# From these examples we can see that it is easier to identify food chains' establishments by their AKA Name

# %% [markdown]
# We can't talk about food in Chicago without mentionning their deep dish pizza, and namely two of their most famous venues: **Giordano's** and **Lou Malnati's** . So let's add them

# %%
food[["Malnati" in aka for aka in food["AKA Name"]]]["AKA Name"].unique()
# Out:
# array(['LouMalnatisPizzeria', 'LouMalnatis'], dtype=object)

# %%
food["AKA Name"]=food["AKA Name"].str.replace('LouMalnatisPizzeria', 'LouMalnatis')

# %%
giordanos=food[["Giordano" in aka for aka in food["AKA Name"]]].index
food.loc[giordanos,"AKA Name"]="Giordanos"

# %%
# We look at establishments with the same AKA name and different adresses
food_chains=food.groupby("AKA Name").Address.nunique().sort_values(ascending=False)
# We will retain food chains with 10 or more establishments
food_chains=food_chains[food_chains>10]
#food_chains[food_chains<10].head(20)
food_chains
# Out:
# AKA Name
# Subway                       293
# DunkinDonuts                 174
# 7Eleven                      118
# Mcdonalds                    111
# Starbucks                    102
# Citgo                         74
# DunkinDonutsBaskinRobbins     72
# Cvs                           71
# BurgerKing                    45
# Marathon                      43
# Walgreens                     42
# JimmyJohns                    42
# Kfc                           41
# Bp                            34
# DollarTree                    33
# Chipotle                      33
# Dominos                       32
# GatewayNewstand               31
# FamilyDollar                  29
# JjFishChicken                 29
# TacoBell                      28
# HaroldsChicken                28
# Wendys                        28
# PizzaHut                      27
# Potbelly                      26
# SharksFishChicken             25
# Giordanos                     24
# Quiznos                       23
# Shell                         23
# Freshii                       23
# AuBonPain                     22
# Wingstop                      22
# HaroldsChickenShack           22
# Popeyes                       21
# LaMichoacana                  19
# Mobil                         18
# CornerBakeryCafe              18
# PotbellyLlc                   16
# JambaJuice                    16
# WhiteHenPantry                15
# PapaJohnsPizza                15
# Herbalife                     14
# WholeFoods                    14
# DollarGeneral                 14
# ArgoTea                       13
# Target                        13
# PretAManger                   12
# PepesMexicanRestaurant        12
# SeeThruChineseKitchen         12
# PeetsCoffeeTea                12
# LouMalnatis                   12
# HalstedStreetDeli             11
# Pockets                       11
# ProteinBar                    11
# Name: Address, dtype: int64

# %%
from sklearn.metrics.pairwise import euclidean_distances
# We are interested in food chains that are rather spread out across the city, for that we will assess the pairwise
# distances of establishments within the same food chain
def food_chain_spread(food_chain):
    location=food[food["AKA Name"]==food_chain][["Latitude","Longitude"]]
    dist_mat=euclidean_distances(location,location)
    return np.sum(dist_mat)/(len(location))
food_chain_spread("Subway")
# Out:
# 462.70888188096853

# %%
spread=pd.Series(food_chains.index).apply(lambda x: food_chain_spread(x))

# %%
fc=pd.DataFrame({"Food_chain":food_chains.index,"number_of_establishments":food_chains.values,"spread":spread})

# %%
fc.sort_values("spread", ascending=False).head(10)
# Out:
#                    Food_chain  number_of_establishments      spread
# 0                      Subway                       293  462.708882
# 3                   Mcdonalds                       111  297.585383
# 1                DunkinDonuts                       174  165.005222
# 2                     7Eleven                       118  111.293185
# 4                   Starbucks                       102  105.625539
# 6   DunkinDonutsBaskinRobbins                        72   87.427120
# 8                  BurgerKing                        45   54.451617
# 12                        Kfc                        41   51.670278
# 22                     Wendys                        28   48.256876
# 15                   Chipotle                        33   40.633834

# %% [markdown]
# Unsuprisingly, fast food chains dominate the list

# %%
food[food["AKA Name"]=="LouMalnatis"]["Address"].unique()
# Out:
# array(['3986 N AVONDALE AVE', '1520 N DAMEN AVE', '4340 N LINCOLN AVE',
#        '956-958 W WRIGHTWOOD AVE', '1120 N STATE ST',
#        '805-811 S STATE ST BLDG', '805 S State ST', '410 N MICHIGAN AVE',
#        '1235 W RANDOLPH ST', '6456 S CICERO AVE', '3859 W OGDEN AVE',
#        '439 N WELLS ST'], dtype=object)

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x='Longitude', y='Latitude', hue='Risk' , data=food[food["AKA Name"]=="LouMalnatis"], ax=ax)
ax.set_title("The distribution of inspections by risk",size=20)
ax.set_xlabel('Longitude')
ax.set_ylabel('LATITUDE')
# Out:
# Text(0, 0.5, 'LATITUDE')

# %%
food.groupby(["AKA Name","Address"])["Inspection ID"].count().sort_values(ascending=False).head(20)
# Out:
# AKA Name                     Address
# Starbucks                    11601 W TOUHY AVE       159
# Mcdonalds                    11601 W TOUHY AVE       148
# ChilisToo                    11601 W TOUHY AVE        80
# UnitedClub                   11601 W TOUHY AVE        75
# ReggiosPizzaExpress          11601 W TOUHY AVE        71
# ArgoTea                      11601 W TOUHY AVE        69
# ManchuWok                    11601 W TOUHY AVE        69
# Mcdonalds                    6900 S LAFAYETTE AVE     60
# FronteraTortasByRickBayless  11601 W TOUHY AVE        58
# TripleAServicesInc           2637 S THROOP ST         56
# LaBombaRestaurant            3221 W ARMITAGE AVE      54
# LaMexicanaTamaleCart         4171 S ARCHER AVE        51
# Mcdonalds                    207 E 35TH ST            49
# JewelFoodStore3345           1224 S WABASH AVE        49
# MarianosFreshMarket          333 E BENTON PL          48
# HudsonNews                   11601 W TOUHY AVE        47
# Food4Less                    7030 S ASHLAND AVE       45
# TheGreatAmericanBagel        11601 W TOUHY AVE        45
# Iyanze                       4623-4627 N BROADWAY     44
# TaqueriaElRanchito           2829 N MILWAUKEE AVE     44
# Name: Inspection ID, dtype: int64

# %%
food[food["Zip"]==60666]["Address"].unique()
# Out:
# array(['11601 W TOUHY AVE', "4000 N O'HARE FIELD", '11555 W TOUHY AVE',
#        '11601 W TOUHY AVE T2 F12', '11601 W TOUHY',
#        '4000 N OHARE AIRPORT', '11601 W TOUHY AVE BLDG M10',
#        '11601 W TOUHY AVE BLDG'], dtype=object)

# %%
food["Address"]
# Out:
# 0           4634-4636 N KEDZIE AVE
# 1                5254 W MADISON ST
# 2            2353 N CALIFORNIA AVE
# 3             3732 N SOUTHPORT AVE
# 4               4014 W CHICAGO AVE
#                     ...
# 194899       2816 N PINE GROVE AVE
# 194900        2336 S WENTWORTH AVE
# 194901    1136 W 122nd St (12200S)
# 194902           2550 W MADISON ST
# 194903           4900 W MADISON ST
# Name: Address, Length: 194781, dtype: object

# %%
food[ (food["AKA Name"]=="Mcdonalds") &(food["Address"]=="6900 S LAFAYETTE AVE")][["Inspection Date","Results","License #","Risk"]].head(60)
# Out:
#        Inspection Date             Results  License #             Risk
# 810         06/21/2019                Pass  2551022.0  Risk 2 (Medium)
# 8322        08/26/2016                Pass  1490035.0  Risk 2 (Medium)
# 8924        06/15/2016                Pass  1490035.0  Risk 2 (Medium)
# 10772       10/21/2015                Pass  1490035.0  Risk 2 (Medium)
# 11047       09/21/2015                Pass  1490035.0  Risk 2 (Medium)
# 13944       08/26/2014                Pass  1490035.0  Risk 2 (Medium)
# 22218       06/24/2011                Pass  1490035.0  Risk 2 (Medium)
# 23064       03/15/2011                Pass  1490035.0  Risk 2 (Medium)
# 25921       02/24/2010                Pass  1490035.0  Risk 2 (Medium)
# 36177       04/03/2019                Pass  2551022.0  Risk 2 (Medium)
# 42175       09/19/2018                Fail  2551022.0  Risk 2 (Medium)
# 43020       09/28/2018  Pass w/ Conditions  2551022.0  Risk 2 (Medium)
# 49307       04/12/2018                Fail  2551022.0  Risk 2 (Medium)
# 50368       04/20/2018                Pass  2551022.0  Risk 2 (Medium)
# 50613       03/08/2018                Fail  2551022.0  Risk 2 (Medium)
# 51872       03/15/2018                Pass  2551022.0  Risk 2 (Medium)
# 54822       11/08/2017                Pass  2551022.0  Risk 2 (Medium)
# 55452       10/19/2017                Pass  2551022.0  Risk 2 (Medium)
# 57221       09/15/2017     Out of Business  1490035.0  Risk 2 (Medium)
# 57670       09/19/2017                Pass  2551022.0  Risk 2 (Medium)
# 61186       09/15/2017                Fail  2551022.0  Risk 2 (Medium)
# 67231       02/10/2017                Fail  1490035.0  Risk 2 (Medium)
# 68678       02/21/2017                Pass  1490035.0  Risk 2 (Medium)
# 73077       12/22/2016                Pass  1490035.0  Risk 2 (Medium)
# 79396       08/11/2016                Pass  1490035.0  Risk 2 (Medium)
# 87207       02/25/2016                Pass  1490035.0  Risk 2 (Medium)
# 89763       12/14/2015                Pass  1490035.0  Risk 2 (Medium)
# 93266       11/24/2015                Pass  1490035.0  Risk 2 (Medium)
# 94224       02/17/2016                Pass  1490035.0  Risk 2 (Medium)
# 104291      03/05/2015                Pass  1490035.0  Risk 2 (Medium)
# 107586      03/31/2015                Pass  1490035.0  Risk 2 (Medium)
# 107737      03/24/2015                Fail  1490035.0  Risk 2 (Medium)
# 107788      04/22/2015                Pass  1490035.0  Risk 2 (Medium)
# 109919      01/30/2015  Pass w/ Conditions  1490035.0  Risk 2 (Medium)
# 116247      08/15/2014                Fail  1490035.0  Risk 2 (Medium)
# 123452      04/11/2014  Pass w/ Conditions  1490035.0  Risk 2 (Medium)
# 125059      05/02/2014                Pass  1490035.0  Risk 2 (Medium)
# 127279      04/28/2014  Pass w/ Conditions  1490035.0  Risk 2 (Medium)
# 136766      09/04/2013  Pass w/ Conditions  1490035.0  Risk 2 (Medium)
# 139738      07/01/2013                Pass  1490035.0  Risk 2 (Medium)
# 141784      06/06/2013  Pass w/ Conditions  1490035.0  Risk 2 (Medium)
# 143758      02/05/2013                Fail  1490035.0  Risk 2 (Medium)
# 145738      03/26/2013                Pass  1490035.0  Risk 2 (Medium)
# 146042      02/13/2013                Pass  1490035.0  Risk 2 (Medium)
# 146854      03/13/2013                Pass  1490035.0  Risk 2 (Medium)
# 148767      11/16/2012                Pass  1490035.0  Risk 2 (Medium)
# 151354      10/26/2012                Pass  1490035.0  Risk 2 (Medium)
# 154044      07/30/2012     Out of Business     8010.0  Risk 2 (Medium)
# 154419      08/15/2012                Pass  1490035.0  Risk 2 (Medium)
# 155096      07/30/2012     Out of Business  1383412.0  Risk 2 (Medium)
# 157100      07/30/2012                Pass  1490035.0  Risk 2 (Medium)
# 158638      02/21/2012                Fail  1490035.0  Risk 2 (Medium)
# 158689      03/29/2012                Pass  1490035.0  Risk 2 (Medium)
# 158885      02/29/2012                Fail  1490035.0  Risk 2 (Medium)
# 165280      11/21/2011                Pass  1490035.0  Risk 2 (Medium)
# 165957      01/20/2012                Pass  1490035.0  Risk 2 (Medium)
# 166899      09/08/2011                Pass  1490035.0  Risk 2 (Medium)
# 172849      08/04/2011                Pass  1490035.0  Risk 2 (Medium)
# 174260      04/22/2011                Pass  1490035.0  Risk 2 (Medium)
# 180302      01/13/2011                Pass  1490035.0  Risk 2 (Medium)

# %%
food["Inspection Date"]
# Out:
# 0         10/25/2019
# 1         10/24/2019
# 2         10/24/2019
# 3         10/24/2019
# 4         10/24/2019
#              ...
# 194899    03/09/2010
# 194900    01/13/2010
# 194901    02/18/2010
# 194902    01/28/2010
# 194903    02/18/2010
# Name: Inspection Date, Length: 194781, dtype: object

# %%
alias1=pd.read_csv("restaurant_aliases_1_norating_1.csv")
alias2=pd.read_csv("restaurant_aliases_2_norating.csv")
alias3=pd.read_csv("restaurant_aliases_3_norating.csv")
alias=pd.concat([alias1,alias2,alias3])
alias.drop(columns=["Unnamed: 0"],inplace=True)
pd_alias=pd.merge(food,alias,how="left",left_on="License #",right_on="License #")
pd_alias
# Out:
#         Inspection ID                              DBA Name  \
# 0             2320519                     salam  restaurant
# 1             2320443                       jordan discount
# 2             2320451                 pretty cool ice cream
# 3             2320388                        bombastic cafe
# 4             2320389  all things are possible for kids inc
# ...               ...                                   ...
# 208515         176553            wee care daycare preschool
# 208516         118311         the noodle vietnamese cuisine
# 208517         164336                                 white
# 208518         120320                     johnnys ice house
# 208519         176291                      joes barbque inc
#
#                               AKA Name  License #  \
# 0                      SalamRestaurant  2002822.0
# 1                       JordanDiscount  2694525.0
# 2                   PrettyCoolIceCream  2616833.0
# 3                        BombasticCafe  2678198.0
# 4       AllThingsArePossibleForKidsInc  2215965.0
# ...                                ...        ...
# 208515         WeeCareDaycarePreschool  1718419.0
# 208516      TheNoodleVietnameseCuisine  1228229.0
# 208517                           White    26431.0
# 208518                 JohnnysIceHouse  1963593.0
# 208519                     JoesBarbque    18234.0
#
#                        Facility Type             Risk  \
# 0                         Restaurant    Risk 1 (High)
# 1                      Grocery Store     Risk 3 (Low)
# 2                         Restaurant    Risk 1 (High)
# 3                         Restaurant  Risk 2 (Medium)
# 4       Children's Services Facility    Risk 1 (High)
# ...                              ...              ...
# 208515       Daycare (Under 2 Years)    Risk 1 (High)
# 208516                    Restaurant    Risk 1 (High)
# 208517                        School    Risk 1 (High)
# 208518                    Restaurant  Risk 2 (Medium)
# 208519                    Restaurant    Risk 1 (High)
#
#                        Address_x     City State      Zip Inspection Date  \
# 0         4634-4636 N KEDZIE AVE  CHICAGO    IL  60625.0      10/25/2019
# 1              5254 W MADISON ST  CHICAGO    IL  60644.0      10/24/2019
# 2          2353 N CALIFORNIA AVE  CHICAGO    IL  60647.0      10/24/2019
# 3           3732 N SOUTHPORT AVE  CHICAGO    IL  60613.0      10/24/2019
# 4             4014 W CHICAGO AVE  CHICAGO    IL  60651.0      10/24/2019
# ...                          ...      ...   ...      ...             ...
# 208515     2816 N PINE GROVE AVE  CHICAGO    IL  60657.0      03/09/2010
# 208516      2336 S WENTWORTH AVE  CHICAGO    IL  60616.0      01/13/2010
# 208517  1136 W 122nd St (12200S)  CHICAGO    IL  60643.0      02/18/2010
# 208518         2550 W MADISON ST  CHICAGO    IL  60612.0      01/28/2010
# 208519         4900 W MADISON ST  CHICAGO    IL  60644.0      02/18/2010
#
#                 Inspection Type             Results  \
# 0       Complaint Re-Inspection                Pass
# 1         License Re-Inspection                Pass
# 2                       Canvass                Pass
# 3                       License                Fail
# 4                       License                Pass
# ...                         ...                 ...
# 208515    License Re-Inspection                Fail
# 208516                  Canvass  Pass w/ Conditions
# 208517                  Canvass                Pass
# 208518                  License                Pass
# 208519  Complaint Re-Inspection                Pass
#
#                                                Violations   Latitude  \
# 0                                        0. None Reported  41.965719
# 1                                        0. None Reported  41.880455
# 2       37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.924363
# 3       53. TOILET FACILITIES: PROPERLY CONSTRUCTED, S...  41.949883
# 4       54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILI...  41.895468
# ...                                                   ...        ...
# 208515  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...  41.933388
# 208516  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...  41.849892
# 208517  35. WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTR...  41.672337
# 208518                                   0. None Reported  41.881233
# 208519                                   0. None Reported  41.880571
#
#         Longitude                                  Location  \
# 0      -87.708538  (-87.70853756167853, 41.965719017423005)
# 1      -87.757290   (-87.75728976536573, 41.88045497430518)
# 2      -87.697255   (-87.69725539567338, 41.92436282156778)
# 3      -87.664242    (-87.6642417785868, 41.94988264936109)
# 4      -87.726665    (-87.7266648149535, 41.89546788877342)
# ...           ...                                       ...
# 208515 -87.641509   (-87.6415090848372, 41.933388339085965)
# 208516 -87.632092   (-87.63209186010796, 41.84989156785116)
# 208517 -87.650553   (-87.65055320582842, 41.67233661078134)
# 208518 -87.690390   (-87.69038958620825, 41.88123342371891)
# 208519 -87.747957  (-87.74795724892677, 41.880571145964275)
#
#                      Address_y                   Name  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2       2353 N CALIFORNIA AVE   PRETTY COOL ICE CREAM
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 208515                     NaN                    NaN
# 208516                     NaN                    NaN
# 208517                     NaN                    NaN
# 208518                     NaN                    NaN
# 208519                     NaN                    NaN
#
#                                 alias
# 0                                 NaN
# 1                                 NaN
# 2       pretty-cool-ice-cream-chicago
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 208515                            NaN
# 208516                            NaN
# 208517                            NaN
# 208518                            NaN
# 208519                            NaN
#
# [208520 rows x 20 columns]

# %%
pd_alias["Inspection Type"] = pd_alias["Inspection Type"].map(lambda x: x.lower())
pd_alias["Inspection Type"] = pd_alias["Inspection Type"].map(lambda x: re.sub('re-', 're', x))
pd_alias["Inspection Type"] = pd_alias["Inspection Type"].map(lambda x:'food poisoning' if ('sfp' in x or 'fbi' in x or 'sick' in x or 'poisoning' in x ) else x)

# %%
pd_alias=pd_alias[pd_alias["Inspection Type"]=="food poisoning"]

# %%
pd_alias["Results"].unique()
# Out:
# array(['Pass w/ Conditions', 'Pass', 'Fail'], dtype=object)

# %%
results=["Pass","Fail","Pass w/ Conditions"]
pd_alias=pd_alias[pd_alias["Results"].isin(results)]
starting_alias=pd_alias[~pd_alias["alias"].isnull()]

# %%
remaining_alias=pd_alias[pd_alias["alias"].isnull()]
remaining_alias.to_csv("remaining_alias.csv")

# %%
fcfp=starting_alias[starting_alias["AKA Name"].isin(food_chains.index)]

# %%
starting_alias.to_csv("starting_alias.csv")

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x='Longitude', y='Latitude', hue='AKA Name' , data=fcfp ,ax=ax)
ax.set_title("The distribution of inspections by risk",size=20)
ax.set_xlabel('Longitude')
ax.set_ylabel('LATITUDE')
# Out:
# Text(0, 0.5, 'LATITUDE')
